# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('earthquakes_raw.csv')
df
# Out:
#        Unnamed: 0                      time   latitude   longitude  depth  \
# 0               0  1950-01-03T11:26:31.960Z  33.940667 -115.888167   6.00
# 1               1  1950-01-05T13:45:49.270Z  33.574833 -119.321500   6.00
# 2               2  1950-01-07T09:37:34.330Z  31.983500 -116.819167   6.00
# 3               3  1950-01-09T13:24:57.060Z  34.066167 -116.959000   0.04
# 4               4  1950-01-09T21:40:36.260Z  33.752333 -116.018667   6.00
# 5               5  1950-01-11T21:41:35.660Z  33.945667 -118.179833   3.44
# 6               6  1950-01-13T05:07:20.500Z  33.977667 -116.412500   6.00
# 7               7  1950-01-14T19:52:30.000Z  40.217000 -124.417000    NaN
# 8               8  1950-01-14T19:53:38.530Z  37.024000 -119.730000   6.00
# 9               9  1950-01-18T01:55:51.000Z  40.500000 -110.500000    NaN
# 10             10  1950-01-19T09:33:49.110Z  33.801167 -118.502000   6.00
# 11             11  1950-01-20T16:17:05.820Z  33.155667 -116.004000   6.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50711 entries, 0 to 50710
# Data columns (total 23 columns):
# Unnamed: 0         50711 non-null int64
# time               50711 non-null object
# latitude           50711 non-null float64
# longitude          50711 non-null float64
# depth              50173 non-null float64
# mag                50711 non-null float64
# magType            50654 non-null object
# nst                42182 non-null float64
# gap                45350 non-null float64
# dmin               32870 non-null float64
# rms                47136 non-null float64
# net                50711 non-null object
# id                 50711 non-null object
# updated            50711 non-null object
# place              50711 non-null object
# type               50711 non-null object
# horizontalError    35309 non-null float64
# depthError         41462 non-null float64
# magError           27155 non-null float64
# magNst             42884 non-null float64
# ...

# %%
df.dtypes == float
# Out:
# Unnamed: 0         False
# time               False
# latitude            True
# longitude           True
# depth               True
# mag                 True
# magType            False
# nst                 True
# gap                 True
# dmin                True
# rms                 True
# net                False
# id                 False
# updated            False
# place              False
# type               False
# horizontalError     True
# depthError          True
# magError            True
# magNst              True
# status             False
# locationSource     False
# magSource          False
# dtype: bool

# %%
df.drop('nst', axis=1, inplace=True)

# %%
df.head()

# %%
int_cols = df[['latitude','longitude','depth','mag','nst','gap','dmin','rms','horizontalError','depthError','magError','magNst']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d3b0a7421f67> in <module>
# ----> 1 int_cols = df[['latitude','longitude','depth','mag','nst','gap','dmin','rms','horizontalError','depthError','magError','magNst']]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
sns.heatmap(int_cols, annot=True)

# %%
len(list(int_cols))
# Out:
# 11

# %%
sns.heatmap(int_cols, annot=True, annot_kws={"size": 7})
sns.plt.show()

# %%
int_cols.corr()
# Out:
#                  latitude  longitude     depth       mag       gap      dmin  \
# latitude         1.000000  -0.036000  0.058503 -0.068627 -0.248202 -0.344897
# longitude       -0.036000   1.000000 -0.030512 -0.004712 -0.110961  0.208197
# depth            0.058503  -0.030512  1.000000  0.103167  0.091645 -0.040557
# mag             -0.068627  -0.004712  0.103167  1.000000  0.082710  0.162474
# gap             -0.248202  -0.110961  0.091645  0.082710  1.000000  0.658889
# dmin            -0.344897   0.208197 -0.040557  0.162474  0.658889  1.000000
# rms             -0.082364   0.124802 -0.011964  0.089992  0.129082  0.282550
# horizontalError -0.133255   0.024474 -0.020909  0.100642  0.385565  0.509554
# depthError      -0.375428   0.046553 -0.037062  0.112145  0.645040  0.644356
# magError        -0.094241  -0.004827  0.037343 -0.039380 -0.031829 -0.091362
# magNst          -0.174426   0.092496  0.007350 -0.032026 -0.187411 -0.151378
#
# ...

# %%
df.mag.sort_values(ascending=False)
