# %% [markdown]
# Predicting Rental Prices in New York

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

import data_cleaning as dc
from sklearn import metrics
# %matplotlib inline

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split

# %%
def get_df():
    useful = ['order_id', 'customer_id', 'order_purchase_timestamp', 'order_delivered_customer_date',
           'order_estimated_delivery_date','payment_type','payment_value', 'review_id', 'review_score', 'review_comment_message','review_creation_date', 'customer_city', 'customer_state','product_id', 'seller_id','price', 
            'freight_value','product_name_lenght', 'product_description_lenght',
           'product_photos_qty', 'product_weight_g', 'product_length_cm',
           'product_height_cm', 'product_width_cm','product_category_name_english']
    df = pd.read_csv('data/products_full.csv')
    df.columns
    df1 = pd.DataFrame(df, columns=useful)
    df1.to_csv('./data/products_clean.csv', index=True)

# %%
df = pd.read_csv('products_clean.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3fe097eeac95> in <module>
# ----> 1 df = pd.read_csv('products_clean.csv')
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'products_clean.csv' does not exist: b'products_clean.csv'

# %%
#importing dataframes and cleaning
df = pd.read_csv('data/products_full.csv')
df.drop(columns = ['Unnamed: 0', 'review_comment_message', 'order_status','order_purchase_timestamp','order_approved_at','payment_sequential','review_id','review_comment_title','customer_unique_id'])
df.drop(columns= [df.columns[23]], inplace=True)
df.dropna(inplace=True)
df.info()
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (9,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11743 entries, 3 to 116565
# Data columns (total 40 columns):
# Unnamed: 0                       11743 non-null float64
# order_id                         11743 non-null object
# customer_id                      11743 non-null object
# order_status                     11743 non-null object
# order_purchase_timestamp         11743 non-null object
# order_approved_at                11743 non-null object
# order_delivered_carrier_date     11743 non-null object
# order_delivered_customer_date    11743 non-null object
# order_estimated_delivery_date    11743 non-null object
# payment_sequential               11743 non-null object
# payment_type                     11743 non-null object
# payment_installments             11743 non-null float64
# payment_value                    11743 non-null float64
# review_id                        11743 non-null object
# review_score                     11743 non-null float64
# review_comment_title             11743 non-null object
# review_comment_message           11743 non-null object
# review_creation_date             11743 non-null object
# review_answer_timestamp          11743 non-null object
# customer_unique_id               11743 non-null object
# customer_zip_code_prefix         11743 non-null float64
# customer_city                    11743 non-null object
# customer_state                   11743 non-null object
# product_id                       11743 non-null object
# seller_id                        11743 non-null object
# shipping_limit_date              11743 non-null object
# price                            11743 non-null float64
# freight_value                    11743 non-null float64
# product_category_name            11743 non-null object
# product_name_lenght              11743 non-null float64
# product_description_lenght       11743 non-null float64
# product_photos_qty               11743 non-null float64
# product_weight_g                 11743 non-null float64
# product_length_cm                11743 non-null float64
# product_height_cm                11743 non-null float64
# product_width_cm                 11743 non-null float64
# product_category_name_english    11743 non-null object
# seller_zip_code_prefix           11743 non-null float64
# seller_city                      11743 non-null object
# seller_state                     11743 non-null object
# dtypes: float64(15), object(25)
# memory usage: 3.7+ MB

# %%
#create list of continuous variables
cont_features = []

for colname, coltype in df.dtypes.iteritems():
    if coltype in [np.float64, np.int64]:
        cont_features.append(colname)
        
df_cont = pd.DataFrame(df, columns=cont_features)

# %%
#create list of categorical variables
cat_features = []

for colname, coltype in df.dtypes.iteritems():
    if coltype in [np.object]:
        cat_features.append(colname)
        
df_cat = pd.DataFrame(df, columns=cont_features)

# %%
# Create X and y then split in train and test
features = [col for col in df.columns if col != 'review_score']
X = df_cont.loc[:, features]
y = df.loc[:, 'review_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

#Create X test and X train from continuous variables
X_train_cont = X_train.loc[:, cont_features]
X_test_cont = X_test.loc[:, cont_features]
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Imputer

# Impute missing values with median using Imputer from sklearn.preprocessing
impute = Imputer(strategy='median')
impute.fit(X_train_cont)

X_train_imputed = impute.transform(X_train_cont)

# Fit the model and print R2 and MSE for train and test
linreg = LinearRegression()
linreg.fit(X_train_imputed, y_train)

print('Training r^2:', linreg.score(X_train_imputed, y_train))
print('Training MSE:', mean_squared_error(y_train, linreg.predict(X_train_imputed)))
# Out:
# Training r^2: 0.02561266980820731
# Training MSE: 2.270705289527559
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.preprocessing import StandardScaler

# Scale the train and test data
ss = StandardScaler()
ss.fit(X_train_imputed)

X_train_imputed_scaled = ss.transform(X_train_imputed)

# %%
linreg_norm = LinearRegression()
linreg_norm.fit(X_train_imputed_scaled, y_train)

print('Training r^2:', linreg_norm.score(X_train_imputed_scaled, y_train))
print('Training MSE:', mean_squared_error(y_train, linreg_norm.predict(X_train_imputed_scaled)))
# Out:
# Training r^2: 0.025612669808207533
# Training MSE: 2.2707052895275583

# %%
# Create X_cat which contains only the categorical variables
X_train_cat = X_train.loc[:, cat_features]

#Fill nans with a value indicating that that it is missing
X_train_cat.fillna(value='missing', inplace=True)

# %%
# # Create X and y then split in train and test
# features = [col for col in df.columns if col != 'review_score']
# X = df_cat.loc[:, features]
# y = df.loc[:, 'review_score']

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

# #Create X test and X train from continuous variables
# X_train_cat = X_train.loc[:, cont_features]
# X_test_cat = X_test.loc[:, cont_features]

# %%
from sklearn.preprocessing import OneHotEncoder

# OneHotEncode Categorical variables
ohe = OneHotEncoder()
X_train_ohe = ohe.fit_transform(X_train_cat)

columns = ohe.get_feature_names(input_features=X_train_cat.columns)
cat_train_df = pd.DataFrame(X_train_ohe.todense(), columns=columns)

# %%
X_train_all = pd.concat([pd.DataFrame(X_train_imputed_scaled), cat_train_df], axis = 1)

# %%
linreg_all = LinearRegression()
linreg_all.fit(X_train_all, y_train)

print('Training r^2:', linreg_all.score(X_train_all, y_train))
print('Training MSE:', mean_squared_error(y_train, linreg_all.predict(X_train_all)))
# Out:
# Training r^2: 0.025612669808207533
# Training MSE: 2.2707052895275583

# %% [markdown]
# Next Steps:
# - Data Cleaning / Proper Join
# - Ridge / Lasso / Elastic
# - Lamdba / Alpha
# - Feature re-selection if low R2 after cleaning
# - Cross-validation
# - Test Data!

# %%
alphas = [0.05,0.5,0.1,0.01]

from sklearn.linear_model import Ridge

def ridge(list):
    for x in list:
        # Train model setting alpha (lambda) to 0.05
        ridge = Ridge(alpha=x, normalize=True)
        #Fit Ridge model to training data
        ridge.fit(X_train_all, y_train)
        y_predict_ridge = ridge.predict(X_train_all)
        # Calculate R^2 and mse
        print('Training r^2:',ridge.score(X_train_all, y_train))
        print('Training MSE:',mean_squared_error(y_train,y_predict_ridge))
        
ridge(alphas)

# %%
df.head()
# Out:
#                             order_id                       customer_id  \
# 3   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 18  dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 29  f3e7c359154d965827355f39d6b1fdac  62b423aab58096ca514ba6aa06be2f98
# 31  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 32  acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
#
#    order_status order_purchase_timestamp    order_approved_at  \
# 3     delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 18    delivered      2018-06-07 19:03:12  2018-06-12 23:31:02
# 29    delivered      2018-08-09 11:44:40  2018-08-10 03:24:51
# 31    delivered      2018-06-04 00:00:13  2018-06-05 00:35:10
# 32    delivered      2018-06-04 00:00:13  2018-06-05 00:35:10
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 3           2018-07-26 14:31:00           2018-08-07 15:27:45
# 18          2018-06-11 14:54:00           2018-06-21 15:34:32
# 29          2018-08-10 12:29:00           2018-08-13 18:24:27
# 31          2018-06-05 13:24:00           2018-06-16 15:20:55
# 32          2018-06-05 13:24:00           2018-06-16 15:20:55
#
#    order_estimated_delivery_date payment_sequential payment_type  ...  \
# 3            2018-08-13 00:00:00                  1       boleto  ...
# 18           2018-07-04 00:00:00                  1  credit_card  ...
# 29           2018-08-17 00:00:00                  1       boleto  ...
# 31           2018-07-18 00:00:00                  1  credit_card  ...
# 32           2018-07-18 00:00:00                  1  credit_card  ...
#
#     product_description_lenght  product_photos_qty product_weight_g  \
# 3                        178.0                 1.0            400.0
# 18                       991.0                 3.0            150.0
# 29                       115.0                 1.0            600.0
# 31                       233.0                 1.0          10950.0
# 32                       300.0                 1.0            350.0
#
#     product_length_cm product_height_cm product_width_cm  \
# 3                19.0              13.0             19.0
# 18               20.0              20.0             20.0
# 29               33.0              13.0             25.0
# 31               41.0              40.0             40.0
# 32               31.0              10.0             12.0
#
#    product_category_name_english seller_zip_code_prefix     seller_city  \
# 3                      perfumery                31570.0  belo horizonte
# 18                     perfumery                71931.0        brasilia
# 29                    stationery                14910.0       tabatinga
# 31                          baby                14910.0       tabatinga
# 32                          baby                14940.0        ibitinga
#
#    seller_state
# 3            SP
# 18           DF
# 29           SP
# 31           SP
# 32           SP
#
# [5 rows x 38 columns]

# %%
df.corr()
# Out:
#                             payment_installments  payment_value  review_score  \
# payment_installments                    1.000000       0.299748     -0.051022
# payment_value                           0.299748       1.000000     -0.103434
# review_score                           -0.051022      -0.103434      1.000000
# customer_zip_code_prefix                0.071640       0.096585     -0.020116
# price                                   0.283300       0.772462     -0.015179
# freight_value                           0.205044       0.391028     -0.030930
# product_name_lenght                    -0.006597      -0.000444     -0.005843
# product_description_lenght              0.031689       0.171217      0.002359
# product_photos_qty                      0.002210       0.015487      0.027220
# product_weight_g                        0.181021       0.336331     -0.041889
# product_length_cm                       0.114075       0.189024     -0.012294
# product_height_cm                       0.124616       0.226054     -0.050806
# product_width_cm                        0.123221       0.168209     -0.011252
# seller_zip_code_prefix                  0.064437       0.080902      0.013453
#
#                             customer_zip_code_prefix     price  freight_value  \
# payment_installments                        0.071640  0.283300       0.205044
# payment_value                               0.096585  0.772462       0.391028
# review_score                               -0.020116 -0.015179      -0.030930
# customer_zip_code_prefix                    1.000000  0.073435       0.267545
# price                                       0.073435  1.000000       0.421534
# freight_value                               0.267545  0.421534       1.000000
# product_name_lenght                         0.028867  0.017833       0.048312
# product_description_lenght                  0.034466  0.190251       0.125262
# product_photos_qty                          0.026312  0.058033       0.023168
# product_weight_g                            0.009283  0.323182       0.596267
# product_length_cm                           0.013152  0.177757       0.375169
# product_height_cm                           0.030447  0.194355       0.372700
# product_width_cm                           -0.007720  0.167112       0.352219
# seller_zip_code_prefix                      0.091363  0.098480       0.185321
#
#                             product_name_lenght  product_description_lenght  \
# payment_installments                  -0.006597                    0.031689
# payment_value                         -0.000444                    0.171217
# review_score                          -0.005843                    0.002359
# customer_zip_code_prefix               0.028867                    0.034466
# price                                  0.017833                    0.190251
# freight_value                          0.048312                    0.125262
# product_name_lenght                    1.000000                    0.111285
# product_description_lenght             0.111285                    1.000000
# product_photos_qty                     0.189350                    0.149255
# product_weight_g                       0.020377                    0.097780
# product_length_cm                      0.043266                    0.067275
# product_height_cm                     -0.038586                    0.090526
# product_width_cm                       0.035966                   -0.035837
# seller_zip_code_prefix                -0.001367                    0.049468
#
#                             product_photos_qty  product_weight_g  \
# payment_installments                  0.002210          0.181021
# payment_value                         0.015487          0.336331
# review_score                          0.027220         -0.041889
# customer_zip_code_prefix              0.026312          0.009283
# price                                 0.058033          0.323182
# freight_value                         0.023168          0.596267
# product_name_lenght                   0.189350          0.020377
# product_description_lenght            0.149255          0.097780
# product_photos_qty                    1.000000          0.013151
# product_weight_g                      0.013151          1.000000
# product_length_cm                     0.046598          0.540725
# product_height_cm                    -0.012862          0.599439
# product_width_cm                     -0.013285          0.521449
# seller_zip_code_prefix               -0.079631          0.021451
#
#                             product_length_cm  product_height_cm  \
# payment_installments                 0.114075           0.124616
# payment_value                        0.189024           0.226054
# review_score                        -0.012294          -0.050806
# customer_zip_code_prefix             0.013152           0.030447
# price                                0.177757           0.194355
# freight_value                        0.375169           0.372700
# product_name_lenght                  0.043266          -0.038586
# product_description_lenght           0.067275           0.090526
# product_photos_qty                   0.046598          -0.012862
# product_weight_g                     0.540725           0.599439
# product_length_cm                    1.000000           0.241755
# product_height_cm                    0.241755           1.000000
# product_width_cm                     0.586541           0.285818
# seller_zip_code_prefix               0.046541           0.012791
#
#                             product_width_cm  seller_zip_code_prefix
# payment_installments                0.123221                0.064437
# payment_value                       0.168209                0.080902
# review_score                       -0.011252                0.013453
# customer_zip_code_prefix           -0.007720                0.091363
# price                               0.167112                0.098480
# freight_value                       0.352219                0.185321
# product_name_lenght                 0.035966               -0.001367
# product_description_lenght         -0.035837                0.049468
# product_photos_qty                 -0.013285               -0.079631
# product_weight_g                    0.521449                0.021451
# product_length_cm                   0.586541                0.046541
# product_height_cm                   0.285818                0.012791
# product_width_cm                    1.000000               -0.001510
# seller_zip_code_prefix             -0.001510                1.000000

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.9, normalize=True)
lasso.fit(X_train_all, y_train)
y_predict_lasso = lasso.predict(X_train_all)
# calculating mse
print('Training MSE:',mean_squared_error(y_train,y_predict_lasso))
print('Training r^2:',lasso.score(X_train_all, y_train))

# %%
from sklearn.linear_model import ElasticNet

elastic = ElasticNet(alpha=0.05, l1_ratio=0.5, normalize=False)
elastic.fit(X_train_all,y_train)
y_predict_elastic = elastic.predict(X_train_all)
#calculating mse
print('Training MSE:', mean_squared_error(y_train, y_predict_elastic))
print('Training r^2:', elastic.score(X_train_all,y_train))
