# %%
import pandas as pd
import numpy as np

import matplotlib as plt
import seaborn as sns

import data_cleaning as dc

# %%
df = pd.read_csv('estimated_rent.csv')
df2 = pd.read_csv('distance_nearest_subway.csv')
df3 = pd.read_csv('real_estate_price_transport.csv')

# %%
df['address'] = df.addr
df.set_index('address', inplace=True)
df.drop(columns=['addr','Unnamed: 0','Unnamed: 0.1'], inplace=True)

df2.set_index('address', inplace=True)

# %%
df2.drop(columns=['Unnamed: 0','Unnamed: 0.1'], inplace=True)
df2.head()
# Out:
#                       num_within_dist   station line  \
# address
# 8650 BAY 16TH STREET                3   79th St    D
# 8650 BAY 16TH STREET                3  20th Ave    D
# 8650 BAY 16TH STREET                3  18th Ave    D
# 70 BAY 20TH STREET                  2  20th Ave    D
# 70 BAY 20TH STREET                  2  18th Ave    D
#
#                                                    geometry   stat_lng  \
# address
# 8650 BAY 16TH STREET  POINT (-74.0005828 40.61315889999999) -74.000583
# 8650 BAY 16TH STREET  POINT (-73.9981743 40.60467689999999) -73.998174
# 8650 BAY 16TH STREET         POINT (-74.0015925 40.6077357) -74.001593
# 70 BAY 20TH STREET    POINT (-73.9981743 40.60467689999999) -73.998174
# 70 BAY 20TH STREET           POINT (-74.0015925 40.6077357) -74.001593
#
#                        stat_lat    add_lng    add_lat  dist_miles
# address
# 8650 BAY 16TH STREET  40.613159 -74.005338  40.607264    0.477642
# ...

# %%
df.head()
# Out:
#                       RegionID     neighborhood sale_date  sale_price  \
# address
# 360 MANHATTAN AVENUE    270958  upper west side   2012-05    695000.0
# 360 MANHATTAN AVENUE    270958  upper west side   2012-03    665000.0
# 360 MANHATTAN AVENUE    270958  upper west side   2012-02    721000.0
# 360 MANHATTAN AVENUE    270958  upper west side   2013-08    955000.0
# 130 MANHATTAN AVENUE    270958  upper west side   2012-12   2100000.0
#
#                       zip_code  rent_estimate
# address
# 360 MANHATTAN AVENUE   10026.0           2664
# 360 MANHATTAN AVENUE   10026.0           2575
# 360 MANHATTAN AVENUE   10026.0           2796
# 360 MANHATTAN AVENUE   10026.0           3319
# 130 MANHATTAN AVENUE   10025.0           8155

# %%
df_full = df.join(df2, on=df.index)
df_full.drop(columns='key_0', inplace=True)

# %%
df3.set_index('address', inplace=True)

# %%
df_fuller = df_full.join(df3, on=df_full.index, rsuffix='real_estate')

# %%
df_fuller.head()
# Out:
#                                      key_0  RegionID     neighborhood  \
# address
# 360 MANHATTAN AVENUE  360 MANHATTAN AVENUE    270958  upper west side
# 360 MANHATTAN AVENUE  360 MANHATTAN AVENUE    270958  upper west side
# 360 MANHATTAN AVENUE  360 MANHATTAN AVENUE    270958  upper west side
# 360 MANHATTAN AVENUE  360 MANHATTAN AVENUE    270958  upper west side
# 360 MANHATTAN AVENUE  360 MANHATTAN AVENUE    270958  upper west side
#
#                      sale_date  sale_price  zip_code  rent_estimate  \
# address
# 360 MANHATTAN AVENUE   2012-05    695000.0   10026.0           2664
# 360 MANHATTAN AVENUE   2012-05    695000.0   10026.0           2664
# 360 MANHATTAN AVENUE   2012-05    695000.0   10026.0           2664
# 360 MANHATTAN AVENUE   2012-05    695000.0   10026.0           2664
# 360 MANHATTAN AVENUE   2012-05    695000.0   10026.0           2664
#
#                       num_within_dist                    station   line  ...  \
# ...

# %%
for i in df_fuller.columns:
    print(i,len(df_fuller.loc[df_fuller[i]==0,:]))
